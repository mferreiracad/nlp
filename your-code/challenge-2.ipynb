# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk
import ssl
import pandas as pd
import re

# %%
# your code here
data = pd.read_csv('training.csv', sep = ',', encoding ='latin-1', header = None )

# %%
columns_names = ['target', 'ids', 'date', 'flag', 'user', 'text']
data.columns = columns_names

# %%
data['text']
# Out:
# 0          @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          is upset that he can't update his Facebook by ...
# 2          @Kenichan I dived many times for the ball. Man...
# 3            my whole body feels itchy and like its on fire
# 4          @nationwideclass no, it's not behaving at all....
#                                  ...
# 1599995    Just woke up. Having no school is the best fee...
# 1599996    TheWDB.com - Very cool to hear old Walt interv...
# 1599997    Are you ready for your MoJo Makeover? Ask me f...
# 1599998    Happy 38th Birthday to my boo of alll time!!! ...
# 1599999    happy #charitytuesday @theNSPCC @SparksCharity...
# Name: text, Length: 1600000, dtype: object

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here
def clean_up(s):
    lower = s.lower()
    no_url = re.sub('http\S+', '',lower)
    str_list = re.findall('[a-z]+',no_url)
    return ' '.join(str_list)
import nltk
nltk.download('punkt')
def tokenize(s):
    tokens = word_tokenize(s)
    return tokens
from nltk.stem.porter import*
nltk.download('wordnet')
def stem_and_lemmatize(s):
    s_l_l = []
    ps = PorterStemmer() 
    lemmatizer = WordNetLemmatizer() 
    for x in s:
        lem = lemmatizer.lemmatize(x)
        st = ps.stem(lem)
        s_l_l.append(st)
    return s_l_l

from nltk.corpus import stopwords
nltk.download('stopwords')
def remove_stopwords(s):
    stop_words = set(stopwords.words('english'))
    filtered_sentence = [w for w in s if not w in stop_words]
    return filtered_sentence
# Out:
# [nltk_data] Downloading package punkt to /Users/miguel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/miguel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/miguel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = data.sample(20000)

# %%
blabla = []
for x in df['text']:
    a = remove_stopwords(stem_and_lemmatize(tokenize(clean_up(x))))
    blabla.append(a)

# %%
blablu=[]
for x in blabla:
    a = " ".join(x)
    blablu.append(a)

# %%
df['text_processed']=blabla

# %%
df
# Out:
#          target         ids                          date      flag  \
# 639856        0  2234824188  Thu Jun 18 23:49:52 PDT 2009  NO_QUERY
# 1232534       4  1991987574  Mon Jun 01 08:00:34 PDT 2009  NO_QUERY
# 1388359       4  2053016522  Sat Jun 06 02:56:31 PDT 2009  NO_QUERY
# 1588068       4  2191032487  Tue Jun 16 04:21:26 PDT 2009  NO_QUERY
# 1294933       4  2003599053  Tue Jun 02 06:49:27 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 689386        0  2251752847  Sat Jun 20 04:28:42 PDT 2009  NO_QUERY
# 1252701       4  1996765329  Mon Jun 01 15:39:06 PDT 2009  NO_QUERY
# 143991        0  1881861064  Fri May 22 05:43:41 PDT 2009  NO_QUERY
# 1550362       4  2183748329  Mon Jun 15 14:55:59 PDT 2009  NO_QUERY
# 951366        4  1824223699  Sun May 17 00:30:16 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 639856   jokerrocks0217  @jasmineplusunny I don't ur song...and bcuz u ...
# 1232534      SmilingImp  just bought #aion CE  money well wasted  ha ha ha
# 1388359      MarieAlina                                       awake again
# 1588068        KandaceM  @goodfellas773 yuk @ the oatmeal but it made m...
# 1294933        saucy_15  @Vicerella right back at you gorgeous! xoxo bi...
# ...                 ...                                                ...
# 689386         SamDolan                                   Grr off to work
# 1252701        dozywozy            Heading to the pool with @jimmygraham!
# 143991        tim_yates  @attilacsordas Ignore me...it doesn't   Need t...
# 1550362           MSPxo              @mileycyrus you can count on my vote
# 951366       lindseybp1  @ChrisEYB thanks for that.  hope you guys had ...
#
#                                             text_processed
# 639856   [jasmineplusunni, ur, song, bcuz, u, said, u, ...
# 1232534  [bought, aion, ce, money, well, wast, ha, ha, ha]
# 1388359                                             [awak]
# 1588068  [goodfella, yuk, oatmeal, made, want, bowl, ce...
# 1294933  [vicerella, right, back, gorgeou, xoxo, big, l...
# ...                                                    ...
# 689386                                         [grr, work]
# 1252701                          [head, pool, jimmygraham]
# 143991   [attilacsorda, ignor, need, read, first, twit,...
# 1550362                           [mileycyru, count, vote]
# 951366   [chriseyb, thank, hope, guy, good, time, detroit]
#
# [20000 rows x 7 columns]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here
#bow_vect = CountVectorizer(max_features=5000)
#X = bow_vect.fit_transform(df['text_processed']).toarray()
# your code here
nova_list = []

for x in df["text_processed"]:
    for word in x:
        nova_list.append(word)

nova_list = nltk.FreqDist(nova_list)
        
words_t = list(nova_list.keys())[:5000]
words_t
# Out:
# ['jasmineplusunni',
#  'ur',
#  'song',
#  'bcuz',
#  'u',
#  'said',
#  'miss',
#  'bought',
#  'aion',
#  'ce',
#  'money',
#  'well',
#  'wast',
#  'ha',
#  'awak',
#  'goodfella',
#  'yuk',
#  'oatmeal',
#  'made',
#  'want',
#  'bowl',
#  'cereal',
#  'vicerella',
#  'right',
#  'back',
#  'gorgeou',
#  'xoxo',
#  'big',
#  'love',
#  'keytarsauru',
#  'defens',
#  'tay',
#  'rock',
#  'find',
#  'scari',
#  'miley',
#  'amp',
#  'taylor',
#  'share',
#  'boy',
#  'cdstore',
#  'didnt',
#  'tint',
#  'got',
#  'ta',
#  'go',
#  'jb',
#  'bum',
#  'school',
#  'bubba',
#  'learn',
#  'test',
#  'oralexam',
#  'finish',
#  'thi',
#  'year',
#  'metal',
#  'realli',
#  'fuck',
#  'stop',
#  'talk',
#  'real',
#  'gt',
#  'shit',
#  'make',
#  'sad',
#  'thepauldaniel',
#  'gran',
#  'onc',
#  'lost',
#  'hous',
#  'key',
#  'onli',
#  'next',
#  'day',
#  'fridg',
#  'might',
#  'worth',
#  'look',
#  'case',
#  'theproperharlot',
#  'ru',
#  'town',
#  'tri',
#  'text',
#  'landlin',
#  'work',
#  'fun',
#  'confus',
#  'cheryldle',
#  'kind',
#  'soul',
#  'food',
#  'spin',
#  'put',
#  'stuf',
#  'collard',
#  'green',
#  'get',
#  'tast',
#  'wan',
#  'na',
#  'black',
#  'hair',
#  'teusday',
#  'sweeeeeet',
#  'hope',
#  'yur',
#  'okay',
#  'x',
#  'gerrymay',
#  'thank',
#  'much',
#  'vote',
#  'end',
#  'may',
#  'spot',
#  'til',
#  'help',
#  'kangurujack',
#  'great',
#  'enjoy',
#  'still',
#  'coudn',
#  'power',
#  'soup',
#  'accumul',
#  'stuff',
#  'spent',
#  'minut',
#  'organ',
#  'room',
#  'month',
#  'jandersonmus',
#  'jessaanderson',
#  'garag',
#  'sale',
#  'start',
#  'home',
#  'fuckin',
#  'bu',
#  'mile',
#  'away',
#  'gig',
#  'foot',
#  'bit',
#  'think',
#  'toe',
#  'broke',
#  'prodigi',
#  'haha',
#  'sober',
#  'southendgem',
#  'alway',
#  'stuck',
#  'control',
#  'tour',
#  'dubay',
#  'whoa',
#  'twitter',
#  'hey',
#  'dana',
#  'caus',
#  'stupid',
#  'wee',
#  'fill',
#  'garbag',
#  'water',
#  'dump',
#  'final',
#  'bed',
#  'ago',
#  'long',
#  'walk',
#  'run',
#  'fed',
#  'troubl',
#  'keep',
#  'touch',
#  'could',
#  'someth',
#  'pleas',
#  'met',
#  'tyler',
#  'drummer',
#  'danger',
#  'summer',
#  'wish',
#  'wa',
#  'feel',
#  'kindr',
#  'spirit',
#  'w',
#  'also',
#  'nice',
#  'live',
#  'togeth',
#  'one',
#  'lol',
#  'happi',
#  'famili',
#  'rt',
#  'victim',
#  'ident',
#  'theft',
#  'omg',
#  'cntm',
#  'nap',
#  'sinc',
#  'ani',
#  'sleep',
#  'tweet',
#  'dream',
#  'american',
#  'tweeter',
#  'probabl',
#  'surgeri',
#  'done',
#  'today',
#  'chrome',
#  'whine',
#  'soundandvis',
#  'awww',
#  'suddenli',
#  'veri',
#  'agre',
#  'parsnipzilla',
#  'would',
#  'come',
#  'messeng',
#  'thrown',
#  'uber',
#  'hissi',
#  'fit',
#  'florida',
#  'gosh',
#  'went',
#  'glad',
#  'javi',
#  'say',
#  'small',
#  'bo',
#  'im',
#  'hungri',
#  'check',
#  'messag',
#  'imeem',
#  'eat',
#  'watch',
#  'fave',
#  'seri',
#  'tv',
#  'nataliebejarano',
#  'late',
#  'odyssey',
#  'oliv',
#  'twist',
#  'alic',
#  'adventur',
#  'wonderland',
#  'tho',
#  'time',
#  'thenn',
#  'borrow',
#  'sakit',
#  'ng',
#  'tyan',
#  'ko',
#  'need',
#  'gingerdoesgolf',
#  'ouch',
#  'kinda',
#  'cut',
#  'tee',
#  'dj',
#  'loki',
#  'take',
#  'celtic',
#  'laker',
#  'chuck',
#  'dane',
#  'cook',
#  'star',
#  'trek',
#  'demon',
#  'survivor',
#  'www',
#  'woodyradio',
#  'com',
#  'kick',
#  'show',
#  'luv',
#  'rememb',
#  'ed',
#  'mcmahon',
#  'die',
#  'listen',
#  'eminem',
#  'mfm',
#  'remind',
#  'bruno',
#  'stunt',
#  'mtv',
#  'movi',
#  'award',
#  'world',
#  'hug',
#  'use',
#  'cuz',
#  'revis',
#  'cognit',
#  'model',
#  'chillin',
#  'skool',
#  'wit',
#  'friendz',
#  'srri',
#  'mac',
#  'feelbad',
#  'jaimeleigh',
#  'evil',
#  'machin',
#  'hell',
#  'garyve',
#  'dude',
#  'guy',
#  'congrat',
#  'hicourtney',
#  'super',
#  'couldnt',
#  'stay',
#  'longer',
#  'swim',
#  'soon',
#  'sit',
#  'lay',
#  'becaus',
#  'iphon',
#  'charg',
#  'cabl',
#  'short',
#  'total',
#  'practic',
#  'karaok',
#  'chop',
#  'karaokeloung',
#  'good',
#  'repentyoursin',
#  'bore',
#  'shaundiviney',
#  'aww',
#  'gone',
#  'ambduckett',
#  'wonder',
#  'whi',
#  'call',
#  'excit',
#  'new',
#  'outgrown',
#  'fact',
#  'appl',
#  'oh',
#  'god',
#  'steve',
#  'mariahsukfan',
#  'first',
#  'game',
#  'nd',
#  'bout',
#  'insid',
#  'see',
#  'visitor',
#  'post',
#  'pic',
#  'tonight',
#  'sarahh',
#  'miser',
#  'luci',
#  'lu',
#  'terroris',
#  'romeo',
#  'carlenek',
#  'charcoal',
#  'gril',
#  'present',
#  'throw',
#  'fell',
#  'asleep',
#  'q',
#  'vendor',
#  'bingo',
#  'pay',
#  'gener',
#  'amount',
#  'night',
#  'break',
#  'london',
#  'phone',
#  'danii',
#  'answer',
#  'mum',
#  'came',
#  'shoe',
#  'n',
#  'bag',
#  'wed',
#  'tomorrow',
#  'yay',
#  'frantic',
#  'shop',
#  'charleneortiz',
#  'turn',
#  'wi',
#  'fi',
#  'coz',
#  'dad',
#  'mad',
#  'internet',
#  'suppos',
#  'soccer',
#  'alreadi',
#  'aidan',
#  'sick',
#  'fat',
#  'must',
#  'exercis',
#  'vulcansmus',
#  'luck',
#  'hard',
#  'part',
#  'fli',
#  'around',
#  'ask',
#  'even',
#  'funni',
#  'noth',
#  'person',
#  'plz',
#  'ebonywelov',
#  'myrtl',
#  'beach',
#  'hunni',
#  'lil',
#  'cloudi',
#  'thenboy',
#  'mayb',
#  'th',
#  'ride',
#  'notorioustori',
#  'expect',
#  'beat',
#  'quickli',
#  'ill',
#  'trade',
#  'last',
#  'titan',
#  'pass',
#  'faffyp',
#  'dunno',
#  'everyth',
#  'drink',
#  'meet',
#  'ceruleanbreez',
#  'without',
#  'doubt',
#  'famou',
#  'bacon',
#  'egg',
#  'chees',
#  'sandwich',
#  'lush',
#  'deannawhit',
#  'bnc',
#  'thing',
#  'rush',
#  'morn',
#  'shew',
#  'pm',
#  'cinema',
#  'termin',
#  'head',
#  'befor',
#  'rain',
#  'set',
#  'felt',
#  'theme',
#  'music',
#  'order',
#  'queen',
#  'politicalcrunch',
#  'sign',
#  'peoplebrows',
#  'light',
#  'know',
#  'yet',
#  'saw',
#  'though',
#  'teacher',
#  'give',
#  'homework',
#  'left',
#  'actual',
#  'academ',
#  'appar',
#  'mine',
#  'flickl',
#  'aw',
#  'babe',
#  'allianz',
#  'kpmg',
#  'main',
#  'client',
#  'involv',
#  'wifey',
#  'lt',
#  'mkrigsman',
#  'like',
#  'headach',
#  'knew',
#  'anyon',
#  'teach',
#  'heartincuff',
#  'paganvixen',
#  'life',
#  'australia',
#  'anyth',
#  'happen',
#  'g',
#  'f',
#  'sat',
#  'outsid',
#  'ksud',
#  'mandi',
#  'va',
#  'fabul',
#  'ladi',
#  'let',
#  'juici',
#  'detail',
#  'gettin',
#  'readi',
#  'church',
#  'ridata',
#  'cf',
#  'card',
#  'imag',
#  'toy',
#  'stori',
#  'quot',
#  'almost',
#  'lover',
#  'fine',
#  'frenzi',
#  'beauti',
#  'sweetli',
#  'bellu',
#  'kidney',
#  'age',
#  'annoy',
#  'kayleelovexx',
#  'chat',
#  'johncmay',
#  'jester',
#  'doctor',
#  'dont',
#  'scare',
#  'incas',
#  'send',
#  'hospit',
#  'xx',
#  'chopelaugh',
#  'save',
#  'grace',
#  'hardcor',
#  'femal',
#  'cop',
#  'downtim',
#  'cast',
#  'earl',
#  'cool',
#  'leon',
#  'snoozinsiouxzen',
#  'profil',
#  'ncnp',
#  'spread',
#  'wealth',
#  'barri',
#  'soetoro',
#  'aka',
#  'obama',
#  'hungryyi',
#  'pizza',
#  'peopl',
#  'buy',
#  'poetic',
#  'violenc',
#  'dnt',
#  'yucci',
#  'smell',
#  'bad',
#  'lmao',
#  'relax',
#  'hammock',
#  'ate',
#  'cemhurturk',
#  'solut',
#  'macbookpro',
#  'robotjohnni',
#  'aaag',
#  'resid',
#  'hottweet',
#  'v',
#  'davi',
#  'somewher',
#  'terilynn',
#  'ufp',
#  'natur',
#  'mug',
#  'krazykorean',
#  'bio',
#  'definit',
#  'lot',
#  'mom',
#  'move',
#  'via',
#  'addthi',
#  'issu',
#  'attent',
#  'missshimri',
#  'thweet',
#  'sure',
#  'lilyroseallen',
#  'fyi',
#  'imposs',
#  'fan',
#  'add',
#  'myspac',
#  'name',
#  'allen',
#  'doesnt',
#  'alright',
#  'promo',
#  'code',
#  'redeem',
#  'kiwi',
#  'word',
#  'advic',
#  'keyborad',
#  'leav',
#  'alvarezthornton',
#  'paulaabdul',
#  'slept',
#  'read',
#  'littl',
#  'lazi',
#  'saturday',
#  'best',
#  'closer',
#  'monday',
#  'nicca',
#  'idea',
#  'mean',
#  'bb',
#  'sub',
#  'angel',
#  'timmi',
#  'kantrn',
#  'sound',
#  'perfectli',
#  'reason',
#  'jasonbradburi',
#  'ball',
#  'gpu',
#  'emmanuelgadenn',
#  'twollar',
#  'complet',
#  'hahaha',
#  'express',
#  'son',
#  'face',
#  'leg',
#  'burn',
#  'woke',
#  'stretch',
#  'contort',
#  'nearli',
#  'quadrapaleg',
#  'dementedpuppet',
#  'safari',
#  'aggress',
#  'cach',
#  'dn',
#  'local',
#  'ip',
#  'dev',
#  'server',
#  'aduuuh',
#  'betee',
#  'found',
#  'locavor',
#  'way',
#  'produc',
#  'shed',
#  'tear',
#  'search',
#  'carolazerlin',
#  'welcom',
#  'stratosphear',
#  'heart',
#  'tote',
#  'pale',
#  'foh',
#  'nvrshtnvr',
#  'shizz',
#  'wid',
#  'cold',
#  'tummi',
#  'sore',
#  'courtenaypress',
#  'ijaaaaooo',
#  'angelsupastar',
#  'round',
#  'friend',
#  'bbc',
#  'film',
#  'appoint',
#  'thenewbnb',
#  'smiley',
#  'strand',
#  'chin',
#  'stand',
#  'shape',
#  'samrosey',
#  'repli',
#  'aint',
#  'honey',
#  'con',
#  'blue',
#  'raini',
#  'sutton',
#  'fair',
#  'anthromorph',
#  'crazi',
#  'hello',
#  'weneedjon',
#  'jone',
#  'nooowwwwwwwwwww',
#  'wrong',
#  'demi',
#  'forget',
#  'highli',
#  'recommend',
#  'omelett',
#  'rice',
#  'muahahah',
#  'sicken',
#  'soooo',
#  'freak',
#  'jon',
#  'kate',
#  'plu',
#  'poorli',
#  'babi',
#  'girl',
#  'damn',
#  'blast',
#  'skamperdan',
#  'yeah',
#  'till',
#  'level',
#  'bye',
#  'peep',
#  'sunday',
#  'four',
#  'surprisingli',
#  'spend',
#  'sissi',
#  'prolli',
#  'eclips',
#  'page',
#  'yahyyi',
#  'close',
#  'gpa',
#  'ge',
#  'intro',
#  'class',
#  'mess',
#  'aesthet',
#  'hate',
#  'fail',
#  'bank',
#  'account',
#  'neg',
#  'ironphreak',
#  'tip',
#  'agh',
#  'throat',
#  'suck',
#  'gay',
#  'saddest',
#  'lifetim',
#  'theroughguid',
#  'poor',
#  'car',
#  'dope',
#  'inc',
#  'earli',
#  'bless',
#  'everyon',
#  'doe',
#  'tonsilit',
#  'never',
#  'ice',
#  'lolli',
#  'middl',
#  'co',
#  'desper',
#  'housewif',
#  'susan',
#  'greeeat',
#  'natblingluvsfli',
#  'easi',
#  'netflix',
#  'dannymacr',
#  'dissidentfuri',
#  'better',
#  'later',
#  'influcx',
#  'cours',
#  'beddi',
#  'hugsi',
#  'zephyrk',
#  'followfriday',
#  'buckhollywood',
#  'twit',
#  'man',
#  'strong',
#  'alcohol',
#  'salvag',
#  'either',
#  'stefi',
#  'ickieepoo',
#  'charlen',
#  'yoiu',
#  'ny',
#  'ashley',
#  'comment',
#  'favorit',
#  'homebuild',
#  'declar',
#  'bankruptci',
#  'mcstain',
#  'louisvil',
#  'nadiale',
#  'drop',
#  'marmit',
#  'cover',
#  'bread',
#  'floor',
#  'fatal',
#  'error',
#  'depart',
#  'ankita',
#  'gaba',
#  'congratul',
#  'initi',
#  'itsonlyword',
#  'yard',
#  'acr',
#  'wilcox',
#  'trip',
#  'ok',
#  'least',
#  'homeground',
#  'updat',
#  'twitterfon',
#  'app',
#  'exonumi',
#  'hotdog',
#  'barelyyjoy',
#  'shaggi',
#  'clown',
#  'babyjew',
#  'sorri',
#  'lucki',
#  'beyond',
#  'samitbasu',
#  'guilti',
#  'shall',
#  'powercut',
#  'juli',
#  'guess',
#  'skype',
#  'date',
#  'torileigh',
#  'macbook',
#  'repair',
#  'himynameisros',
#  'kno',
#  'gotten',
#  'mcfli',
#  'jona',
#  'brother',
#  'noooooooooooooooooooo',
#  'vulcanstev',
#  'amyfranko',
#  'question',
#  'possibl',
#  'chang',
#  'rest',
#  'nervou',
#  'taisaintboogi',
#  'restrict',
#  'current',
#  'product',
#  'comput',
#  'stilll',
#  'jonathanrknight',
#  'dm',
#  'goodknight',
#  'charmoon',
#  'ikea',
#  'restaur',
#  'mall',
#  'free',
#  'coffe',
#  'jordaaaannnn',
#  'combustiblesong',
#  'tehstalk',
#  'shut',
#  'discovagina',
#  'xd',
#  'peac',
#  'outski',
#  'klbz',
#  'origazgirl',
#  'chanc',
#  'technic',
#  'problem',
#  'brook',
#  'david',
#  'birthday',
#  'cake',
#  'pick',
#  'marvel',
#  'sang',
#  'drlancesweet',
#  'whole',
#  'andi',
#  'booth',
#  'karacornflak',
#  'depriv',
#  'pack',
#  'sister',
#  'canada',
#  'crazyspeak',
#  'quick',
#  'quit',
#  'foodland',
#  'job',
#  'full',
#  'heap',
#  'te',
#  'limit',
#  'ch',
#  'tell',
#  'iamsoannoy',
#  'reliev',
#  'stress',
#  'und',
#  'liebesgr',
#  'e',
#  'au',
#  'dem',
#  'duti',
#  'lovedior',
#  'elpasotim',
#  'wow',
#  'tix',
#  'reik',
#  'awesom',
#  'ashleegaston',
#  'breakdown',
#  'hubbi',
#  'cuddl',
#  'dancebabyd',
#  'ohh',
#  'btw',
#  'xoxoxo',
#  'lairbear',
#  'gon',
#  'mommi',
#  'sim',
#  'crash',
#  'desktop',
#  'disabl',
#  'capsul',
#  'fix',
#  'backup',
#  'ohmyseven',
#  ...]

# %%
#as_df = pd.DataFrame(X,columns=bow_vect.get_feature_names())
#as_df.head()
def find_features(n):
    
    words = set(n)
    features = {}
    for w in words_t:
        features[w] = (w in words)

    return features

# %%
featuresets = [(find_features(tweet), target) for (tweet, target) in list(zip(df['text_processed'], df['target']))]

print(len(featuresets))
# Out:
# 20000

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %%
train_set, test_set = featuresets[:2500], featuresets[2500:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %%
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(10)

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
# !git add .
# !git status
# !git commit -m 'last one'
# !git push
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	deleted:    challenge-1.ipynb
# 	deleted:    challenge-2.ipynb
#
# [master c2ded11] last one
#  2 files changed, 2210 deletions(-)
#  delete mode 100644 your-code/challenge-1.ipynb
#  delete mode 100644 your-code/challenge-2.ipynb
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 81.16 MiB | 3.38 MiB/s, done.
# Total 12 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 3 local objects.
# remote: error: Trace: 8f28d4b30a3feb9cfaf1795723b6f1a4dca27de97c43563e3e13f9e0cb71f169
# remote: error: See http://git.io/iEPt8g for more information.
# remote: error: File your-code/training.csv is 227.74 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/mferreiracad/lab-nlp
#  ! [remote rejected] master -> master (pre-receive hook declined)
# error: failed to push some refs to 'https://github.com/mferreiracad/lab-nlp'
